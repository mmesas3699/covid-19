# %% [markdown]
# ## EXTRACT data

# %%
import csv
import requests
import pandas as pd
import io

url_data = requests.get('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-22-2020.csv').content
raw_data = pd.read_csv(io.StringIO(url_data.decode('utf-8')))

# %%
values = raw_data.values

with open('daily.csv', 'w') as csvfile:
    for row in values:
        csvwriter = csv.writer(csvfile, delimiter=',')
        csvwriter.writerow(row)

# %%
base_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/'
dates = ['03-17-2020', '01-23-2020', '01-24-2020']

url = base_url + dates[0] + '.csv'
url
_url = requests.get(url).content
_data = pd.read_csv(io.StringIO(_url.decode('utf-8')))
_values = _data.values
file_name = dates[0] + '.csv'
file_name
_values

# %%
with open(file_name, 'w') as csvfile:
    for row in _values:
        csvwriter = csv.writer(csvfile, delimiter=',')
        csvwriter.writerow(row)
# Out:
#     Province/State                  Country/Region          Last Update  \
# 0            Hubei                           China  2020-03-17T11:53:10
# 1              NaN                           Italy  2020-03-17T18:33:02
# 2              NaN                            Iran  2020-03-17T15:13:09
# 3              NaN                           Spain  2020-03-17T20:53:02
# 4              NaN                         Germany  2020-03-17T18:53:02
# ..             ...                             ...                  ...
# 271            NaN                        Guernsey  2020-03-17T18:33:03
# 272            NaN                          Jersey  2020-03-17T18:33:03
# 273            NaN                     Puerto Rico  2020-03-17T16:13:14
# 274            NaN           Republic of the Congo  2020-03-17T21:33:03
# 275            NaN  occupied Palestinian territory  2020-03-11T20:53:02
#
#      Confirmed  Deaths  Recovered  Latitude  Longitude
# ...

# %%
_data.describe()
# Out:
#           Confirmed       Deaths     Recovered    Latitude   Longitude
# count    276.000000   276.000000    276.000000  276.000000  276.000000
# mean     714.376812    28.641304    292.898551   26.761055    4.273018
# std     4710.730292   248.763367   3391.772577   22.879848   80.561775
# min        0.000000     0.000000      0.000000  -41.454500 -157.498300
# 25%        7.000000     0.000000      0.000000   13.444300  -71.548225
# 50%       37.000000     0.000000      0.000000   33.476500    9.777700
# 75%      161.250000     1.000000      4.250000   42.530375   65.169900
# max    67799.000000  3111.000000  56003.000000   71.706900  174.886000

# %%
colombia = _data['Country/Region'] == 'Colombia'
_data[colombia]
# Out:
#     Province/State Country/Region          Last Update  Confirmed  Deaths  \
# 111            NaN       Colombia  2020-03-17T15:53:12         65       0
#
#      Recovered  Latitude  Longitude
# 111          1    4.5709   -74.2973
